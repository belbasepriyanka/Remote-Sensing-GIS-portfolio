# %% [markdown]
# # Grouped ML validation
# Plant IDs are kept within one fold to reduce repeated-measure leakage.

# %%
from src.data_generation import generate_demo
from src.modeling import flowering_classifier,yield_regression
df=generate_demo()

# %%
flower_metrics, flower_importance, flower_predictions=flowering_classifier(df)
yield_metrics, yield_importance, yield_predictions, plant_summary=yield_regression(df)
flower_metrics, yield_metrics
