# %% [markdown]
# # Dragon Fruit Yield & Flowering Forecasting — exploration
# Synthetic demonstration data only.

# %%
from src.data_generation import generate_demo
df=generate_demo()
df.head()

# %%
df.groupby(['month','species'])[['flower_count','fruit_count']].mean().head(12)
