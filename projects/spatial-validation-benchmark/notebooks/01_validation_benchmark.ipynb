# %% [markdown]
# # Spatial validation benchmark

# %%
from src.data_generation import generate_spatial
from src.benchmark import spatial_cv
spatial_cv(generate_spatial())
