# %% [markdown]
# # Terrain and hydrology demo

# %%
from src.data_generation import generate_dem
from src.terrain import slope_degrees, flow_accumulation_proxy
dem=generate_dem()
slope_degrees(dem).mean(), flow_accumulation_proxy(dem).max()
